# %% [markdown]
# # Filtering NC Financial Health Data from a National Health Database
#  Below are the steps to filter through the county health data from 2014-2015 to include only datapoints associating income and health in counties from North Carolina. This dataset will serve to show how financial health translates into physical health in North Carolina. We will first filter the dataset to only include counties from North Carolina, and then filter to only include the datapoints we choose.

# %% [markdown]
# ## Working with the Raw Data

# %% [markdown]
# Import pandas to enable file editing

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# Have pandas read the file

# %%
df=pd.read_csv("CountyHealthData_2014-2015.csv")

# %% [markdown]
# Run tests to ensure the file was read correctly

# %%
df.shape
# Out:
# (6109, 64)

# %%
df [5:8]
# Out:
#   State Region Division                  County  FIPS  GEOID   SMS Region  \
# 5    AK   West  Pacific      Bethel Census Area  2050   2050  Insuff Data
# 6    AK   West  Pacific  Dillingham Census Area  2070   2070  Insuff Data
# 7    AK   West  Pacific  Dillingham Census Area  2070   2070  Insuff Data
#
#        Year  Premature death  Poor or fair health  ...  Drug poisoning deaths  \
# 5  1/1/2015          12864.0                0.211  ...                    NaN
# 6  1/1/2014           9699.0                0.121  ...                    NaN
# 7  1/1/2015          15057.0                0.121  ...                    NaN
#
#    Uninsured adults  Uninsured children  Health care costs  \
# 5             0.389               0.153             5317.0
# 6             0.384               0.147             6082.0
# 7             0.367               0.154             7204.0
#
#    Could not see doctor due to cost  Other primary care providers  \
# 5                             0.200                         175.0
# 6                             0.152                         119.0
# 7                             0.152                         120.0
#
#    Median household income  Children eligible for free lunch  Homicide rate  \
# 5                    42876                             0.721           18.3
# 6                    47498                             0.636            NaN
# 7                    47930                             0.690            NaN
#
#    Inadequate social support
# 5                        NaN
# 6                      0.305
# 7                        NaN
#
# [3 rows x 64 columns]

# %% [markdown]
# ## Making a North Carolina dataset

# %% [markdown]
# Filter out all data except for counties from North Carolina

# %%
df[df["State"] == "NC"]
# Out:
#      State Region        Division            County   FIPS  GEOID  \
# 3243    NC  South  South Atlantic   Alamance County  37001  37001
# 3244    NC  South  South Atlantic   Alamance County  37001  37001
# 3245    NC  South  South Atlantic  Alexander County  37003  37003
# 3246    NC  South  South Atlantic  Alexander County  37003  37003
# 3247    NC  South  South Atlantic  Alleghany County  37005  37005
# ...    ...    ...             ...               ...    ...    ...
# 3438    NC  South  South Atlantic     Wilson County  37195  37195
# 3439    NC  South  South Atlantic     Yadkin County  37197  37197
# 3440    NC  South  South Atlantic     Yadkin County  37197  37197
# 3441    NC  South  South Atlantic     Yancey County  37199  37199
# 3442    NC  South  South Atlantic     Yancey County  37199  37199
#
#        SMS Region      Year  Premature death  Poor or fair health  ...  \
# 3243    Region 20  1/1/2014           7123.0                0.192  ...
# 3244    Region 20  1/1/2015           7291.0                0.192  ...
# 3245    Region 20  1/1/2014           7974.0                0.178  ...
# 3246    Region 20  1/1/2015           8079.0                0.178  ...
# 3247  Insuff Data  1/1/2014           8817.0                0.234  ...
# ...           ...       ...              ...                  ...  ...
# 3438    Region 20  1/1/2015           8028.0                0.159  ...
# 3439    Region 20  1/1/2014           7893.0                0.207  ...
# 3440    Region 20  1/1/2015           7258.0                0.207  ...
# 3441    Region 15  1/1/2014           6872.0                0.193  ...
# 3442    Region 15  1/1/2015           8917.0                0.193  ...
#
#       Drug poisoning deaths  Uninsured adults  Uninsured children  \
# 3243                  10.48             0.259               0.073
# 3244                  12.38             0.249               0.088
# 3245                  22.74             0.240               0.077
# 3246                  24.04             0.239               0.076
# 3247                  18.18             0.320               0.131
# ...                     ...               ...                 ...
# 3438                   7.31             0.262               0.079
# 3439                  18.45             0.252               0.097
# 3440                  20.21             0.242               0.094
# 3441                  20.79             0.268               0.110
# 3442                  28.02             0.246               0.091
#
#       Health care costs  Could not see doctor due to cost  \
# 3243             8640.0                             0.167
# 3244             9050.0                             0.167
# 3245             9316.0                             0.205
# 3246             9242.0                             0.205
# 3247             9585.0                             0.210
# ...                 ...                               ...
# 3438             9450.0                             0.107
# 3439            10084.0                             0.158
# 3440            10998.0                             0.158
# 3441             7707.0                             0.158
# 3442             7870.0                             0.158
#
#       Other primary care providers  Median household income  \
# 3243                          46.0                    41394
# 3244                          56.0                    43001
# 3245                          30.0                    39655
# 3246                          32.0                    46064
# 3247                          55.0                    34046
# ...                            ...                      ...
# 3438                          77.0                    40772
# 3439                          32.0                    40012
# 3440                          32.0                    40998
# 3441                          79.0                    36019
# 3442                          74.0                    35866
#
#       Children eligible for free lunch  Homicide rate  \
# 3243                             0.444           4.94
# 3244                             0.455           4.60
# 3245                             0.417           6.27
# 3246                             0.449           7.20
# 3247                             0.523            NaN
# ...                                ...            ...
# 3438                             0.556           9.60
# 3439                             0.422           3.76
# 3440                             0.455            NaN
# 3441                             0.477            NaN
# 3442                             0.469            NaN
#
#       Inadequate social support
# 3243                      0.202
# 3244                        NaN
# 3245                      0.273
# 3246                        NaN
# 3247                      0.215
# ...                         ...
# 3438                        NaN
# 3439                      0.241
# 3440                        NaN
# 3441                      0.176
# 3442                        NaN
#
# [200 rows x 64 columns]

# %% [markdown]
# Label this new dataset as "NC_subset"

# %%
NC_subset = df[df["State"] == "NC"].copy()

# %% [markdown]
# Run a test to make sure the data was read correctly

# %%
NC_subset
# Out:
#      State Region        Division            County   FIPS  GEOID  \
# 3243    NC  South  South Atlantic   Alamance County  37001  37001
# 3244    NC  South  South Atlantic   Alamance County  37001  37001
# 3245    NC  South  South Atlantic  Alexander County  37003  37003
# 3246    NC  South  South Atlantic  Alexander County  37003  37003
# 3247    NC  South  South Atlantic  Alleghany County  37005  37005
# ...    ...    ...             ...               ...    ...    ...
# 3438    NC  South  South Atlantic     Wilson County  37195  37195
# 3439    NC  South  South Atlantic     Yadkin County  37197  37197
# 3440    NC  South  South Atlantic     Yadkin County  37197  37197
# 3441    NC  South  South Atlantic     Yancey County  37199  37199
# 3442    NC  South  South Atlantic     Yancey County  37199  37199
#
#        SMS Region      Year  Premature death  Poor or fair health  ...  \
# 3243    Region 20  1/1/2014           7123.0                0.192  ...
# 3244    Region 20  1/1/2015           7291.0                0.192  ...
# 3245    Region 20  1/1/2014           7974.0                0.178  ...
# 3246    Region 20  1/1/2015           8079.0                0.178  ...
# 3247  Insuff Data  1/1/2014           8817.0                0.234  ...
# ...           ...       ...              ...                  ...  ...
# 3438    Region 20  1/1/2015           8028.0                0.159  ...
# 3439    Region 20  1/1/2014           7893.0                0.207  ...
# 3440    Region 20  1/1/2015           7258.0                0.207  ...
# 3441    Region 15  1/1/2014           6872.0                0.193  ...
# 3442    Region 15  1/1/2015           8917.0                0.193  ...
#
#       Drug poisoning deaths  Uninsured adults  Uninsured children  \
# 3243                  10.48             0.259               0.073
# 3244                  12.38             0.249               0.088
# 3245                  22.74             0.240               0.077
# 3246                  24.04             0.239               0.076
# 3247                  18.18             0.320               0.131
# ...                     ...               ...                 ...
# 3438                   7.31             0.262               0.079
# 3439                  18.45             0.252               0.097
# 3440                  20.21             0.242               0.094
# 3441                  20.79             0.268               0.110
# 3442                  28.02             0.246               0.091
#
#       Health care costs  Could not see doctor due to cost  \
# 3243             8640.0                             0.167
# 3244             9050.0                             0.167
# 3245             9316.0                             0.205
# 3246             9242.0                             0.205
# 3247             9585.0                             0.210
# ...                 ...                               ...
# 3438             9450.0                             0.107
# 3439            10084.0                             0.158
# 3440            10998.0                             0.158
# 3441             7707.0                             0.158
# 3442             7870.0                             0.158
#
#       Other primary care providers  Median household income  \
# 3243                          46.0                    41394
# 3244                          56.0                    43001
# 3245                          30.0                    39655
# 3246                          32.0                    46064
# 3247                          55.0                    34046
# ...                            ...                      ...
# 3438                          77.0                    40772
# 3439                          32.0                    40012
# 3440                          32.0                    40998
# 3441                          79.0                    36019
# 3442                          74.0                    35866
#
#       Children eligible for free lunch  Homicide rate  \
# 3243                             0.444           4.94
# 3244                             0.455           4.60
# 3245                             0.417           6.27
# 3246                             0.449           7.20
# 3247                             0.523            NaN
# ...                                ...            ...
# 3438                             0.556           9.60
# 3439                             0.422           3.76
# 3440                             0.455            NaN
# 3441                             0.477            NaN
# 3442                             0.469            NaN
#
#       Inadequate social support
# 3243                      0.202
# 3244                        NaN
# 3245                      0.273
# 3246                        NaN
# 3247                      0.215
# ...                         ...
# 3438                        NaN
# 3439                      0.241
# 3440                        NaN
# 3441                      0.176
# 3442                        NaN
#
# [200 rows x 64 columns]

# %% [markdown]
# Export the new dataset

# %%
NC_subset.to_csv("NC_subset.csv", index=False)

# %% [markdown]
# ## Getting our desired datapoints

# %% [markdown]
# Define the new dataset as "nc".

# %%
nc=pd.read_csv("NC_subset.csv")

# %% [markdown]
# Filter the new dataset to only include the following columns: Median household income, poor or fair health, uninsured adults, uninsured children, inadequate social support, healthcare costs, and could not see doctor due to cost.

# %%
nc[["Median household income", "Poor or fair health", "Uninsured adults", "Uninsured children", "Inadequate social support", "Could not see doctor due to cost", "Health care costs"]][:]
# Out:
#      Median household income  Poor or fair health  Uninsured adults  \
# 0                      41394                0.192             0.259
# 1                      43001                0.192             0.249
# 2                      39655                0.178             0.240
# 3                      46064                0.178             0.239
# 4                      34046                0.234             0.320
# ..                       ...                  ...               ...
# 195                    40772                0.159             0.262
# 196                    40012                0.207             0.252
# 197                    40998                0.207             0.242
# 198                    36019                0.193             0.268
# 199                    35866                0.193             0.246
#
#      Uninsured children  Inadequate social support  \
# 0                 0.073                      0.202
# 1                 0.088                        NaN
# 2                 0.077                      0.273
# 3                 0.076                        NaN
# 4                 0.131                      0.215
# ..                  ...                        ...
# 195               0.079                        NaN
# 196               0.097                      0.241
# 197               0.094                        NaN
# 198               0.110                      0.176
# 199               0.091                        NaN
#
#      Could not see doctor due to cost  Health care costs
# 0                               0.167             8640.0
# 1                               0.167             9050.0
# 2                               0.205             9316.0
# 3                               0.205             9242.0
# 4                               0.210             9585.0
# ..                                ...                ...
# 195                             0.107             9450.0
# 196                             0.158            10084.0
# 197                             0.158            10998.0
# 198                             0.158             7707.0
# 199                             0.158             7870.0
#
# [200 rows x 7 columns]

# %% [markdown]
# Define this new set as "NC_subset1"

# %%
NC_subset1 = nc[["County","Median household income", "Poor or fair health", "Uninsured adults", "Uninsured children", "Inadequate social support", "Could not see doctor due to cost", "Health care costs"]].copy()

# %% [markdown]
# Run a test to check if the data was filtered correctly

# %%
NC_subset1
# Out:
#                County  Median household income  Poor or fair health  \
# 0     Alamance County                    41394                0.192
# 1     Alamance County                    43001                0.192
# 2    Alexander County                    39655                0.178
# 3    Alexander County                    46064                0.178
# 4    Alleghany County                    34046                0.234
# ..                ...                      ...                  ...
# 195     Wilson County                    40772                0.159
# 196     Yadkin County                    40012                0.207
# 197     Yadkin County                    40998                0.207
# 198     Yancey County                    36019                0.193
# 199     Yancey County                    35866                0.193
#
#      Uninsured adults  Uninsured children  Inadequate social support  \
# 0               0.259               0.073                      0.202
# 1               0.249               0.088                        NaN
# 2               0.240               0.077                      0.273
# 3               0.239               0.076                        NaN
# 4               0.320               0.131                      0.215
# ..                ...                 ...                        ...
# 195             0.262               0.079                        NaN
# 196             0.252               0.097                      0.241
# 197             0.242               0.094                        NaN
# 198             0.268               0.110                      0.176
# 199             0.246               0.091                        NaN
#
#      Could not see doctor due to cost  Health care costs
# 0                               0.167             8640.0
# 1                               0.167             9050.0
# 2                               0.205             9316.0
# 3                               0.205             9242.0
# 4                               0.210             9585.0
# ..                                ...                ...
# 195                             0.107             9450.0
# 196                             0.158            10084.0
# 197                             0.158            10998.0
# 198                             0.158             7707.0
# 199                             0.158             7870.0
#
# [200 rows x 8 columns]

# %% [markdown]
# Export the new dataset

# %%
NC_subset1.to_csv("NC_subset1.csv", index=False)
